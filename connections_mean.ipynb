# %%
from src.load_data import PatientLoader
from src.process import NeuroFeatureExtractor

# %%
import os
import numpy as np
from nilearn import plotting
import matplotlib.pyplot as plt

loader = PatientLoader()
extractor = NeuroFeatureExtractor() 

matrices_young = []  
matrices_adult = []  

# 1. NOS MUDAMOS A LA CARPETA DATA
# Esto evita que PatientLoader duplique la palabra "data/"
os.chdir("data")

# 2. EL BUCLE MÁGICO (ahora busca en el directorio actual ".")
for patient_dir in os.listdir("."):
    if not patient_dir.startswith("sub-"):
        continue 
        
    print(f"Procesando paciente: {patient_dir}...")
    patient_id = patient_dir.split('-')[1]
    
    try:
        # AQUÍ LA CLAVE: Le pasamos solo "sub-1004"
        recording = loader.load(patient_dir)
        
        matrix = extractor.extract_functional_connectivity(recording)
        
        if patient_id.startswith('1'):
            matrices_young.append(matrix)
        elif patient_id.startswith('2'):
            matrices_adult.append(matrix)
            
    except Exception as e:
        print(f"Error procesando {patient_dir}: {e}")

# 3. VOLVEMOS A LA CARPETA PRINCIPAL
# Muy importante para no romper las celdas que ejecutes después
os.chdir("..")

print(f"\n¡Procesamiento terminado! Jóvenes: {len(matrices_young)} | Adultos: {len(matrices_adult)}")


# --- VISUALIZACIÓN DE LOS RESULTADOS ---
if len(matrices_young) > 0 and len(matrices_adult) > 0:
    mean_young = np.mean(matrices_young, axis=0)
    mean_adult = np.mean(matrices_adult, axis=0)
    matrix_diff = mean_adult - mean_young

    fig, axes = plt.subplots(1, 3, figsize=(24, 6))

    plotting.plot_matrix(mean_young, axes=axes[0], title="Media Jóvenes (Grupo 1)",
                         vmax=1, vmin=-1, cmap='RdBu_r', colorbar=True)

    plotting.plot_matrix(mean_adult, axes=axes[1], title="Media Adultos (Grupo 2)",
                         vmax=1, vmin=-1, cmap='RdBu_r', colorbar=True)

    plotting.plot_matrix(matrix_diff, axes=axes[2], title="Diferencia (Adultos - Jóvenes)",
                         cmap='coolwarm', colorbar=True) 

    plt.tight_layout()
    plt.show()
else:
    print("No se pudieron extraer matrices para hacer la media.")
# Out:
# Fetching Schaefer Atlas (200 ROIs)...
# [fetch_atlas_schaefer_2018] Dataset found in C:\Users\ainho\nilearn_data\schaefer_2018
# Procesando paciente: sub-1004...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7652CBE0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C3009A0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F768DA370>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1004\func\sub-1004_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 68.5s, 1.1min
# Procesando paciente: sub-1005...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B7A0D0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300700>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76A887C0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1005\func\sub-1005_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 64.6s, 1.1min
# Procesando paciente: sub-1006...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7C2ED280>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7652C340>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C32D670>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1006\func\sub-1006_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 64.4s, 1.1min
# Procesando paciente: sub-1007...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7E940>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE3A0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76B81E20>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1007\func\sub-1007_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 63.6s, 1.1min
# Procesando paciente: sub-1008...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F769CA6D0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2F5820>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76D40A60>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1008\func\sub-1008_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 67.3s, 1.1min
# Procesando paciente: sub-1009...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7ED00>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300DC0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C32DD60>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1009\func\sub-1009_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 65.0s, 1.1min
# Procesando paciente: sub-1010...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7AF17400>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300E50>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1010\func\sub-1010_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 67.4s, 1.1min
# Procesando paciente: sub-1012...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F769CA700>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300610>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C32DD60>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1012\func\sub-1012_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 58.8s, 1.0min
# Procesando paciente: sub-1013...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7AF173D0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C3008E0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F763DB310>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1013\func\sub-1013_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 59.7s, 1.0min
# Procesando paciente: sub-1014...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7EB20>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE940>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76A88580>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1014\func\sub-1014_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 62.9s, 1.0min
# Procesando paciente: sub-1015...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B81E20>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE6D0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7BD51820>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1015\func\sub-1015_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 62.8s, 1.0min
# Procesando paciente: sub-1016...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7BD50CA0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE6D0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76AC0F70>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1016\func\sub-1016_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 61.0s, 1.0min
# Procesando paciente: sub-1017...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300400>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F763DB310>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1017\func\sub-1017_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 61.5s, 1.0min
# Procesando paciente: sub-1018...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76AC00D0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C300E50>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C2F5730>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1018\func\sub-1018_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.0s, 1.0min
# Procesando paciente: sub-1019...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7AF17400>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F76AC0F70>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C2EE670>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1019\func\sub-1019_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 58.6s, 1.0min
# Procesando paciente: sub-1020...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7C2EE9D0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7BD559A0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76B6F6D0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1020\func\sub-1020_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 64.7s, 1.1min
# Procesando paciente: sub-1021...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7C2F5820>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7BD50C40>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1021\func\sub-1021_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 62.2s, 1.0min
# Procesando paciente: sub-1022...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2F54F0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F769FE4C0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1022\func\sub-1022_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.8s, 1.0min
# Procesando paciente: sub-1023...
# Error procesando sub-1023: No such file or no access: 'sub-1023/func/sub-1023_task-rest_dir-AP_run-01_bold.nii.gz'
# Procesando paciente: sub-1024...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7BD51940>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE3A0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76D40A60>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1024\func\sub-1024_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 62.7s, 1.0min
# Procesando paciente: sub-1026...
# Error procesando sub-1026: No such file or no access: 'sub-1026/func/sub-1026_task-rest_dir-AP_run-01_bold.nii.gz'
# Procesando paciente: sub-1027...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7652CF70>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76B6FB50>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1027\func\sub-1027_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 54.5s, 0.9min
# Procesando paciente: sub-1028...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7EEE0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2F5730>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C2ED3A0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1028\func\sub-1028_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.7s, 1.0min
# Procesando paciente: sub-1029...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F769CA700>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7652CAC0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7C2F56D0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1029\func\sub-1029_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.0s, 1.0min
# Procesando paciente: sub-1030...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76B7AA30>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2EE940>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F769CC1C0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1030\func\sub-1030_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 59.2s, 1.0min
# Procesando paciente: sub-1032...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7C2ED700>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7BD55970>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76A83E20>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1032\func\sub-1032_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 65.8s, 1.1min
# Procesando paciente: sub-1033...
# Error procesando sub-1033: No such file or no access: 'sub-1033/anat/sub-1033_T1w.nii.gz'
# Procesando paciente: sub-1034...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7EFD0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F76A7E940>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7B1A5C40>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1034\func\sub-1034_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.1s, 1.0min
# Procesando paciente: sub-1035...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76AC0400>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7652C9D0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F7BD50BE0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1035\func\sub-1035_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 60.3s, 1.0min
# Procesando paciente: sub-1036...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F7BD50C40>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2F5880>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76A88580>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1036\func\sub-1036_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 54.5s, 0.9min
# Procesando paciente: sub-1037...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F769CC4C0>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7652C9D0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F76AA2DC0>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-1037\func\sub-1037_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 57.8s, 1.0min
# Procesando paciente: sub-1038...
# Error procesando sub-1038: No such file or no access: 'sub-1038/func/sub-1038_task-rest_dir-AP_run-01_bold.nii.gz'
# Procesando paciente: sub-1039...
# Error procesando sub-1039: No such file or no access: 'sub-1039/anat/sub-1039_T1w.nii.gz'
# Procesando paciente: sub-1040...
# Error procesando sub-1040: No such file or no access: 'sub-1040/func/sub-1040_task-rest_dir-AP_run-01_bold.nii.gz'
# Procesando paciente: sub-2001...
# Error procesando sub-2001: No such file or no access: 'sub-2001/anat/sub-2001_T1w.nii.gz'
# Procesando paciente: sub-2002...
# Error procesando sub-2002: No such file or no access: 'sub-2002/anat/sub-2002_T1w.nii.gz'
# Procesando paciente: sub-2003...
# Error procesando sub-2003: No such file or no access: 'sub-2003/anat/sub-2003_T1w.nii.gz'
# Procesando paciente: sub-2004...
# [fetch_atlas_harvard_oxford] Dataset found in C:\Users\ainho\nilearn_data\fsl
# [NiftiLabelsMasker.wrapped] loading data from Nifti1Image(
# shape=(91, 109, 91),
# affine=array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]])
# )
# ________________________________________________________________________________
# [Memory] Calling nilearn.maskers.base_masker.filter_and_extract...
# filter_and_extract(<nibabel.nifti1.Nifti1Image object at 0x0000022F76A7E940>, <nilearn.maskers.nifti_labels_masker._ExtractionFunctor object at 0x0000022F7C2F56D0>,
# { 'background_label': 0,
#   'clean_args': None,
#   'clean_kwargs': {},
#   'cmap': 'CMRmap_r',
#   'detrend': True,
#   'dtype': None,
#   'high_pass': 0.01,
#   'high_variance_confounds': False,
#   'keep_masked_labels': True,
#   'labels': None,
#   'labels_img': <nibabel.nifti1.Nifti1Image object at 0x0000022F768DA370>,
#   'low_pass': 0.1,
#   'lut': None,
#   'mask_img': None,
#   'reports': True,
#   'smoothing_fwhm': None,
#   'standardize': 'zscore',
#   'standardize_confounds': True,
#   'strategy': 'mean',
#   't_r': 2,
#   'target_affine': array([[   2.,    0.,    0.,  -90.],
#        [   0.,    2.,    0., -126.],
#        [   0.,    0.,    2.,  -72.],
#        [   0.,    0.,    0.,    1.]]),
#   'target_shape': (91, 109, 91)}, confounds=None, sample_mask=None, dtype=None, memory=Memory(location=nilearn_cache\joblib), memory_level=1, verbose=1)
# [NiftiLabelsMasker.wrapped] Loading data from Nifti1Image('sub-2004\func\sub-2004_task-rest_dir-AP_run-01_bold.nii.gz')
# [NiftiLabelsMasker.wrapped] Resampling images
# D:\Programas\anaconda\envs\neuroimage\lib\site-packages\joblib\memory.py:326: UserWarning: Casting data from int16 to float32
#   return self.func(*args, **kwargs)
# [NiftiLabelsMasker.wrapped] Extracting region signals
# [NiftiLabelsMasker.wrapped] Cleaning extracted signals
# ______________________________________________filter_and_extract - 55.0s, 0.9min
# Procesando paciente: sub-2004-20260520T151132Z-3-001...
# Error procesando sub-2004-20260520T151132Z-3-001: No such file or no access: 'sub-2004-20260520T151132Z-3-001/anat/sub-2004-20260520T151132Z-3-001_T1w.nii.gz'
# Procesando paciente: sub-2004-20260520T151132Z-3-001.zip...
# Error procesando sub-2004-20260520T151132Z-3-001.zip: No such file or no access: 'sub-2004-20260520T151132Z-3-001.zip/anat/sub-2004-20260520T151132Z-3-001.zip_T1w.nii.gz'
# Procesando paciente: sub-2006...
# Error procesando sub-2006: No such file or no access: 'sub-2006/anat/sub-2006_T1w.nii.gz'
# Procesando paciente: sub-2007...
# Error procesando sub-2007: No such file or no access: 'sub-2007/anat/sub-2007_T1w.nii.gz'
# Procesando paciente: sub-2008...
# Error procesando sub-2008: No such file or no access: 'sub-2008/anat/sub-2008_T1w.nii.gz'
# Procesando paciente: sub-2010...
# Error procesando sub-2010: No such file or no access: 'sub-2010/anat/sub-2010_T1w.nii.gz'
# Procesando paciente: sub-2011...
# Error procesando sub-2011: No such file or no access: 'sub-2011/anat/sub-2011_T1w.nii.gz'
# Procesando paciente: sub-2012...
# Error procesando sub-2012: No such file or no access: 'sub-2012/anat/sub-2012_T1w.nii.gz'
# Procesando paciente: sub-2013...
# Error procesando sub-2013: No such file or no access: 'sub-2013/anat/sub-2013_T1w.nii.gz'
# Procesando paciente: sub-2016...
# Error procesando sub-2016: No such file or no access: 'sub-2016/anat/sub-2016_T1w.nii.gz'
# Procesando paciente: sub-2018...
# Error procesando sub-2018: No such file or no access: 'sub-2018/anat/sub-2018_T1w.nii.gz'
# Procesando paciente: sub-2019...
# Error procesando sub-2019: No such file or no access: 'sub-2019/anat/sub-2019_T1w.nii.gz'
# Procesando paciente: sub-2020...
# Error procesando sub-2020: No such file or no access: 'sub-2020/anat/sub-2020_T1w.nii.gz'
# Procesando paciente: sub-2021...
# Error procesando sub-2021: No such file or no access: 'sub-2021/anat/sub-2021_T1w.nii.gz'
# Procesando paciente: sub-2022...
# Error procesando sub-2022: No such file or no access: 'sub-2022/anat/sub-2022_T1w.nii.gz'
# Procesando paciente: sub-2023...
# Error procesando sub-2023: No such file or no access: 'sub-2023/anat/sub-2023_T1w.nii.gz'
# Procesando paciente: sub-2024...
# Error procesando sub-2024: No such file or no access: 'sub-2024/anat/sub-2024_T1w.nii.gz'
# Procesando paciente: sub-2025...
# Error procesando sub-2025: No such file or no access: 'sub-2025/anat/sub-2025_T1w.nii.gz'
# Procesando paciente: sub-2026...
# Error procesando sub-2026: No such file or no access: 'sub-2026/anat/sub-2026_T1w.nii.gz'
# Procesando paciente: sub-2027...
# Error procesando sub-2027: No such file or no access: 'sub-2027/anat/sub-2027_T1w.nii.gz'
# Procesando paciente: sub-2029...
# Error procesando sub-2029: No such file or no access: 'sub-2029/anat/sub-2029_T1w.nii.gz'
# Procesando paciente: sub-2030...
# Error procesando sub-2030: No such file or no access: 'sub-2030/anat/sub-2030_T1w.nii.gz'
# Procesando paciente: sub-2031...
# Error procesando sub-2031: No such file or no access: 'sub-2031/anat/sub-2031_T1w.nii.gz'
# Procesando paciente: sub-2032...
# Error procesando sub-2032: No such file or no access: 'sub-2032/anat/sub-2032_T1w.nii.gz'
# Procesando paciente: sub-2037...
# Error procesando sub-2037: No such file or no access: 'sub-2037/anat/sub-2037_T1w.nii.gz'
# Procesando paciente: sub-2038...
# Error procesando sub-2038: No such file or no access: 'sub-2038/anat/sub-2038_T1w.nii.gz'
#
# ¡Procesamiento terminado! Jóvenes: 28 | Adultos: 1
