# %%
import sys
sys.path.insert(0, '../')

from src.load_data import PatientLoader
from src.process import preprocess

# %% [markdown]
# ## Explore Data

# %%
from nilearn import plotting, image, masking

# %%
file_path = "data/sub-1004"
loader = PatientLoader()
recording = loader.load(file_path)

# %%
# Make an average
data, img = preprocess(recording)
mean_img = image.mean_img(img)
mask3d = masking.compute_epi_mask(mean_img)
mask4d = masking.compute_epi_mask(img)

plotting.plot_roi(
    mask3d,
    bg_img=mean_img,
    title="Mask from 3D mean EPI (compute_epi_mask)",
    display_mode="z",
    cut_coords=10,
)
plotting.plot_roi(
    mask4d,
    bg_img=mean_img,
    title="Mask from 4D EPI (compute_epi_mask)",
    display_mode="z",
    cut_coords=10,
)

# %%
plotting.plot_img(mean_img, title="Mean EPI (SPM auditory)")

# %% [markdown]
# ## **Get the atlas for regions feature extraction**

# %%
from nilearn import datasets

def fetch_schaefer_atlas():
    # Fetch the Schaefer 200 parcels atlas with Yeo 7 or 17 networks
    atlas = datasets.fetch_atlas_schaefer_2018(
        n_rois=200, 
        yeo_networks=7, 
        resolution_mm=1
    )
    return atlas['maps'], atlas['labels']

maps, labels = fetch_schaefer_atlas()
plotting.plot_roi(maps, bg_img=mean_img, title="Schaefer Atlas (200 parcels, Yeo 7 networks)", display_mode="z", cut_coords=10)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 12
#       8         resolution_mm=1
#       9     )
#      10     return atlas['maps'], atlas['labels']
#      11
# ---> 12 maps, labels = fetch_schaefer_atlas()
#      13 plotting.plot_roi(maps, bg_img=mean_img, title="Schaefer Atlas (200 parcels, Yeo 7 networks)", display_mode="z", cut_coords=10)
#
# Cell In[21], line 5, in fetch_schaefer_atlas()
#       3 def fetch_schaefer_atlas():
#       4     # Fetch the Schaefer 200 parcels atlas with Yeo 7 or 17 networks
# ----> 5     atlas = datasets.fetch_atlas_schaefer_2018(
#       6         n_rois=200,
#       7         yeo_networks=7,
#       8         resolution_mm=1
#
# File ~/marcos/master/Q2/NeuroImage/FinalProject/.venv/lib/python3.12/site-packages/nilearn/datasets/atlas.py:2337, in fetch_atlas_schaefer_2018(n_rois, yeo_networks, resolution_mm, data_dir, base_url, resume, verbose)
#    2328 files = [
#    2329     (f, base_url + f, {})
#    2330     for f in [
#    (...)   2333     ]
#    2334 ]
#    2336 dataset_name = "schaefer_2018"
# -> 2337 data_dir = get_dataset_dir(
#    2338     dataset_name, data_dir=data_dir, verbose=verbose
#    2339 )
#    2340 labels_file, atlas_file = fetch_files(
#    2341     data_dir, files, resume=resume, verbose=verbose
#    2342 )
#    2344 lut = pd.read_csv(
#    2345     labels_file,
#    2346     delimiter="\t",
#    2347     names=["index", "name", "r", "g", "b", "fs"],
#    2348 )
#
# File ~/marcos/master/Q2/NeuroImage/FinalProject/.venv/lib/python3.12/site-packages/nilearn/datasets/_utils.py:291, in get_dataset_dir(dataset_name, data_dir, default_paths, verbose)
#     288             short_error_message = getattr(exc, "strerror", str(exc))
#     289             errors.append(f"\n -{path} ({short_error_message})")
# --> 291 raise OSError(
#     292     "Nilearn tried to store the dataset in the following "
#     293     f"directories, but: {''.join(errors)}"
#     294 )
#
# OSError: Nilearn tried to store the dataset in the following directories, but:
#  -/home/marcos/nilearn_data/schaefer_2018 (name 'escape' is not defined)
