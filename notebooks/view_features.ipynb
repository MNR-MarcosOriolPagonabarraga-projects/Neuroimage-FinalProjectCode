# %%
import sys
sys.path.insert(0, '../')

import numpy as np
from src.load_data import ProcessedDataLoader

# %%
data_path = '../data/processed'
data_loader = ProcessedDataLoader(data_path)
data = data_loader.load()

# %%
print("data length:", len(data))
print("Connectivity Matrix", data[0]["corr_matrix"].shape)
print("Activation Time Series", data[0]["activation_time_series"].shape)
print("Labels", f"Adults: {len([1 for i in data if i['label'] == 0])}", f"Youngs: {len([1 for i in data if i['label'] == 1])}")
# Out:
# data length: 1612
# Connectivity Matrix (96, 96)
# Activation Time Series (300, 96)
# Labels Adults: 884 Youngs: 728
